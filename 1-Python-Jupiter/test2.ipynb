# %%
## Add two numbers

1+1
# Out:
# 2

# %%
## Print Something

# %% [markdown]
# Now run

# %%
2+2
# Out:
# 4

# %%
## Basic syntax rules in python
## Case Sensitivity - Single Line comment with a double has ##
## This is a single line comment
'''This is a multi line comment'''
''' Tripple quote is for multi line comments
'''

##  Python is case sensitive
name = "Deepak"
Name = "Manktala"
print(name, Name)
# Out:
# Deepak Manktala

# %%
## Indentation - Python uses indentation to define a block of code . Consistent use of space (4) or a tab is required

# %%
age = 37
if age > 30:
    print(True)
    print(age)
# Out:
# True
# 37

# %%
## Line Continuation (with a Backslash \)
total = 1+2+3+4+5+6+ \
4+5+100
print(total)
# Out:
# 130

# %%
## Multiple statements on a single line with ; semi colon
x=5; y=6; z =7 ; a,b,c = 1,2,3; d = a+b+c; l = x+y+z
print(x,y,z,a,b,c,d,l)
# Out:
# 5 6 7 1 2 3 6 18

# %%
age = 45

# %%
name= "deepak"

# %%
type(age), type(name)
# Out:
# (int, str)

# %%
##type inference
variable = 10
print(type(variable))
variable= "Deepak"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=b

# %%
g=h
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 g=h
#
# NameError: name 'h' is not defined

# %%
## Code example of indentation
if True:
    print("This is the correct indentatio")
    if False:
        print("This will not print as its under False")
    print("This shoudl definitely print")
print("It should print outside the If Block")
# Out:
# This is the correct indentatio
# This shoudl definitely print
# It should print outside the If Block

# %%
a = 100

# %%
## Declaring and Assigning variable
age = 37
name = "Deepak"
is_student = True
height = "5.6"
print("age : ", age )
print("name :", name)
# Out:
# age :  37
# name : Deepak

# %%
## variable naming convention
## variable name should eb descriptive
## variable shoudl only start with alphabet or underscores - can contain alphanumeric and underscores
## variables are name sensitive
## e.g, first_name, last_name, _first_secodn,
## invalid variable name 2firts, first-name, @gal
2first = 78
# Out:
#   Cell In[30], line 7
#     2first = 78
#     ^
# SyntaxError: invalid decimal literal

# %%
first-name = "dsd"
# Out:
#   Cell In[31], line 1
#     first-name = "dsd"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
@name = "Deepak"
# Out:
#   Cell In[32], line 1
#     @name = "Deepak"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
## Python is dyncamically typed- type of variable is determined in the run time
## type checking and conversion
percentage = 56.65
print(type(percentage))
# Out:
# <class 'float'>

# %%
print(str(percentage))
# Out:
# 56.65

# %%
print(int(percentage))
# Out:
# 56

# %%
str1 = "1211"

# %%
int(str1)
# Out:
# 1211

# %%
name = "Deepak"

# %%
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Deepak'

# %%
var= 10
print(var, type(var))
var = 1212.123
print(var, type(var))
# Out:
# 10 <class 'int'>
# 1212.123 <class 'float'>

# %%
age = int(input("what is the age"))
print(age, (type(age)))
# Out:
# 232 <class 'int'>

# %%
## Simple Calc

num1 = float(input("Enter the firts number"))
num2 = float(input("Enter the second number"))

sum = num1+num2

difference = num1 - num2

product = num1 * num2

quotient = num1 / num2

print("Sum",  sum)
print("difference", difference)
print("product", product)
print("Quotient", quotient)
# Out:
# Sum 130.0
# difference -50.0
# product 3600.0
# Quotient 0.4444444444444444
