# %% [markdown]
# TOKENIZATION

# %%
corpus = """ Hello Welcome, welcome to my world. This is my NLP program.
Do complete it for brushing up the learnt and implemented items. Excited!
"""
print(corpus)
# Out:
#  Hello Welcome, welcome to my worl. This is my NLP program.
# Do complete it for brushing up the learnt and implemented items. Excited!

# %%
corpus_2 = """ Hello Welcome, welcome to my world. This is my NLP program.
Do complete it for brushing up the learnt and implemented items. Excited!
"""
print(corpus2)
# Out:
#  Hello Welcome, welcome to my worl. This is my NLP program.
# Do complete it for brushing up the learnt and implemented items. Excited!

# %%
## Tokenization
## Pragraphs --> Sentences
from nltk.tokenize import sent_tokenize

sent_tokenize(corpus)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[8], line 5
#       1 ## Tokenization
#       2 ## Pragraphs --> Sentences
#       3 from nltk.tokenize import sent_tokenize
#       4
# ----> 5 sent_tokenize(corpus)
#
# File c:\Users\deepakm3\Downloads\GenAI_projects\myenv\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File c:\Users\deepakm3\Downloads\GenAI_projects\myenv\Lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
# ...

# %%
import nltk
nltk.download("punkt")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\deepakm3\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\deepakm3\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True
