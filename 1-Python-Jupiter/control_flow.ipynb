# %% [markdown]
# CONTROL FLOW

# %% [markdown]
# PYTHON

# %% [markdown]
# if else if, elif, else - Conditional statements

# %%
## is statement --> if statement evaluates the condition
age = 30 
if age >= 18:
    print ("you are allowed to vote")
# Out:
# you are allowed to vote

# %%
## else
## else statement executes a block of code if the condition in the if statement is false
age = int(input("Enter your age: "))
if age >= 18 and age <=60:
    print("You are an adult between young and mid-age--> You are eligible to vote")
elif age > 60:
    print("You're an OLD gum, vote carefully")
else:
    print("You're a kid, kiddooo! nad you're a minor ")
# Out:
# You're an OLD gum, vote carefully

# %%
## Nested COnditional statements --> Add additional if , else if statemenst within other if statements

## number even, odd, negative
num = int(input("Enter the number"))

if num > 0:
    print("number is positive")

    if num % 2 == 0:
        print("The number is even")
    else:
        print("The number is odd")
elif num == 0:
    print("number is ZERO")
else:
    print ("the number is -ve")
# Out:
# number is positive
# The number is odd

# %% [markdown]
# PRACTICAL EXAMPLES

# %%
## If a year is a leap year using nested listed conditions

year = int(input("Enter the year you want tocheck for leap year test: "))

if year % 4 == 0:
    # print("It is a leap year")
    if year %100 == 0:
        # print("It is a leap year")
        if year %400 ==0:
            print("It is a leap year")
        else:
            print("it is not a leap year")
        # elif:
        #     print("it is not a leap year")
    else:
        print("it is a leap year")
else: 
    print("it is not a leap year")


# else:
#     print("It is not a leap year")
# Out:
# it is a leap year

# %% [markdown]
# SIMPLE CALC

# %%
num1 = float(input("Enter first number:"))
num2 = float(input("Enter second number:"))
operation = input("Enter operation (+, -, *, /, **): ")

if operation == "+":
    print("sum is ", num1+num2)
elif operation == "-":
    print("subtraction is ", num1-num2)
elif operation == "*":
    print("product is ", num1*num2)
elif operation == "/":
    if num2 != 0:
        print("division is ", num1/num2)
    else:
        print("Zero division error")
elif operation == "**":
    print("Exponential  is ", num1**num2)
else:
    print("Thank you for your time")
# Out:
# Zero division error

# %% [markdown]
# Ticket PRICE Program

# %%
age = int(input("Enter your age: "))

if age < 5:
    print ("You're an infant and amster/miss , Your ticket is FREE")
elif age >=5 and age < 18:
    ticket = "$15"
    print("Ticket price is ", ticket)
elif age >=18 and age < 59:
    student = (input("Are you a student, enter 1 if yes, enter 0 if no") )
    # print(student == "1")
    if student == "1":
        print("You're a studnet your ticket is $30")
    else:
        print("You're adult , your ticket price is $ 90")
elif age > 60:
    print("You're an oldy, your ticket price is $40")
# Out:
# You're adult , your ticket price is $ 90
