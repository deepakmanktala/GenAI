# %%
## Data types
## Intergers Example
age = 35
type(age)
# Out:
# int

# %%
af = 287732.3232
type(af)
# Out:
# float

# %%
width = 7.12
heigth = 7821.2
type(width)
# Out:
# float

# %%
## boolean data types
1 == 1
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
is_true = True

# %%
type(is_true)
# Out:
# bool

# %%
bool()
# Out:
# False

# %%
a = 10
b = 10

a == b
# Out:
# True

# %%
type (a == b)
# Out:
# bool

# %%
## common errors
result = "Hello " + str(5)
print(result)
# Out:
# Hello 5

# %%
## Operators
## Arithmetic operations
a = 62
b = 7
add_result = a + b
sub_result = a - b
product_result = a * b
div_result = a/b    ## / will give the float division value
floor_div_result = a // b ## floor value will give the INT value and remove decimal
modulus_result = a % b ## % will give the remainder value
exponential_result = a ** b ## Base 62 7 time is 62 raise to power 7

print (add_result, sub_result, product_result, div_result, floor_div_result, modulus_result, exponential_result)
# Out:
# 69 55 434 8.857142857142858 8 6 3521614606208

# %%
## Comparison operators
## ==
a = 10
b = 10
a == b
# result = (a==b)
# Out:
# True

# %%
str1 = "Deepak"
str2 = "Deepak"

str1 == str2
# Out:
# False

# %%
str1 = "alizeh"
str2 = "alizeh"

str1 != str2

str1 == str2
# Out:
# True

# %%
str3 = "ghds"
str4 = "djsdjs"

str3 != str4
# Out:
# True

# %%
## Greater than operation
num1 = 56
num2 = 78
num1 < num2
# Out:
# True

# %%
num1> num2
# Out:
# False

# %%
num1 = 67
num2 = 67

num1 >= num2 ## Greater than equal to
# Out:
# True

# %% [markdown]
# COMPRISON OPERATORS

# %%
num1 <= num2 ## Less than equla to
# Out:
# True

# %%
## Comparison Opertaors --> == , >= , <=

# %% [markdown]
# ## Logical Operators --> AND , OR, NOT, XOR, XNAND etc.

# %%
x = False
y = False
x and y

result = x and y
result1 = x or y
result2 = not result 
print(result, result1, result2)
# Out:
# False False True

# %% [markdown]
# CREATE a SIMPLE CALCULATOR

# %%
num1 = float(input("Enter the first number:" ))
num2 = float(input("Enter the second number:"))

addition = num1 + num2
subtraction = num1 - num2
product = num1 * num2
division = num1/num2
exponential = num1 ** num2
modulus = num1%num2 # it will give the remainder
floor_division = num1//num2 # it will give the INT output as floor division


print(addition, subtraction, product, division, exponential, modulus, floor_division)
# Out:
# 13.0 -5.0 36.0 0.4444444444444444 262144.0 4.0 0.0
