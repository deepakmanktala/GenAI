# %% [markdown]
# EVENT Hubs Kafka Dmeo using python

# %% [markdown]
# EVENT Hubs can process millions of events per second with low latency, data sent to an event hub using IOT, Fraud detection, Real Time application and Fraud Detection.

# %% [markdown]
# EVENT HUBS Documentation
# Events Hub for integrating withAzure, apache spark for batching or storage adapters. Kafka clusters is under the hood
#
# Event Producers --> Azure Event hubs(with partitions) --> Consumer Gorups (Consumer Group 1, COnsumer Group 2 etc.)
#
# Partitions can be consumer by lots of consumer groups
