# %% [markdown]
# MODULES AND PACKAGES

# %%
import math
math.sqrt(36)
# Out:
# 6.0

# %%
from math import sqrt, pi
print(sqrt(81))
print(sqrt(200))
print(sqrt(100))
print(pi)
# Out:
# 9.0
# 14.142135623730951
# 10.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *
print(sqrt(81))
pi
# Out:
# 9.0
# 3.141592653589793

# %%
from custom_package.my_maths import addition, subtraction

print(addition(10,30))

print(subtraction(100,90))
# Out:
# 40
# 10

# %%
from custom_package import my_maths

my_maths.addition(90,100)
# Out:
# 190
